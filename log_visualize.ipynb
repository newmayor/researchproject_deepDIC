# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
path = '/home/numairahmed/forked_deepDIC/Deep-Dic-deep-learning-based-digital-image-correlation/experiment_numairData/log/log2022_03_02_16:41:26'
log_data = np.loadtxt(path, skiprows=1)
print(log_data)
# Out:
# [[0.00000000e+00 0.00000000e+00 6.56782761e+01]
#  [0.00000000e+00 1.00000000e+00 7.84566879e+01]
#  [0.00000000e+00 2.00000000e+00 4.97176170e+01]
#  ...
#  [1.49000000e+02 3.72000000e+02 1.41464788e-02]
#  [1.49000000e+02 3.73000000e+02 9.93211567e-03]
#  [1.49000000e+02 3.74000000e+02 2.58460641e-02]]

# %%
loss_list = []
for ind in range(150):
    index = log_data[:,0]==ind
    loss = log_data[index]
    avg_loss = sum(loss[:,2])/loss[-1,1]
    loss_list.append(avg_loss)

# %%
plt.figure()
plt.plot(loss_list)
# plt.ylim([0,20])
plt.title('Training loss over epochs')
plt.xlabel('epoch')
plt.ylabel('MSE loss')
plt.show()
